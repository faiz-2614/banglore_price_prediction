# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/Faiz/Desktop/Bengaluru_House_Data.csv')

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
data
data1 = data.drop(['location','society','balcony','availability'],axis=1)
data1
# Out:
#                   area_type       size total_sqft  bath   price
# 0      Super built-up  Area      2 BHK       1056   2.0   39.07
# 1                Plot  Area  4 Bedroom       2600   5.0  120.00
# 2            Built-up  Area      3 BHK       1440   2.0   62.00
# 3      Super built-up  Area      3 BHK       1521   3.0   95.00
# 4      Super built-up  Area      2 BHK       1200   2.0   51.00
# ...                     ...        ...        ...   ...     ...
# 13315        Built-up  Area  5 Bedroom       3453   4.0  231.00
# 13316  Super built-up  Area      4 BHK       3600   5.0  400.00
# 13317        Built-up  Area      2 BHK       1141   2.0   60.00
# 13318  Super built-up  Area      4 BHK       4689   4.0  488.00
# 13319  Super built-up  Area      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
data1.isnull().sum()
# Out:
# area_type      0
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
data1 = data1.dropna()
data1
# Out:
#                   area_type       size total_sqft  bath   price
# 0      Super built-up  Area      2 BHK       1056   2.0   39.07
# 1                Plot  Area  4 Bedroom       2600   5.0  120.00
# 2            Built-up  Area      3 BHK       1440   2.0   62.00
# 3      Super built-up  Area      3 BHK       1521   3.0   95.00
# 4      Super built-up  Area      2 BHK       1200   2.0   51.00
# ...                     ...        ...        ...   ...     ...
# 13315        Built-up  Area  5 Bedroom       3453   4.0  231.00
# 13316  Super built-up  Area      4 BHK       3600   5.0  400.00
# 13317        Built-up  Area      2 BHK       1141   2.0   60.00
# 13318  Super built-up  Area      4 BHK       4689   4.0  488.00
# 13319  Super built-up  Area      1 BHK        550   1.0   17.00
#
# [13247 rows x 5 columns]

# %%
data1.isnull().sum()
# Out:
# area_type     0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
data['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
data1.isnull().sum()
# Out:
# area_type     0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
data.dropna()
data['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
data2=data1.copy()
data2['bhk'] = data1['size'].str.split(' ').str[0].astype(int)
data2
# Out:
#                   area_type       size total_sqft  bath   price  bhk
# 0      Super built-up  Area      2 BHK       1056   2.0   39.07    2
# 1                Plot  Area  4 Bedroom       2600   5.0  120.00    4
# 2            Built-up  Area      3 BHK       1440   2.0   62.00    3
# 3      Super built-up  Area      3 BHK       1521   3.0   95.00    3
# 4      Super built-up  Area      2 BHK       1200   2.0   51.00    2
# ...                     ...        ...        ...   ...     ...  ...
# 13315        Built-up  Area  5 Bedroom       3453   4.0  231.00    5
# 13316  Super built-up  Area      4 BHK       3600   5.0  400.00    4
# 13317        Built-up  Area      2 BHK       1141   2.0   60.00    2
# 13318  Super built-up  Area      4 BHK       4689   4.0  488.00    4
# 13319  Super built-up  Area      1 BHK        550   1.0   17.00    1
#
# [13247 rows x 6 columns]

# %%
data2.head()
# Out:
#               area_type       size total_sqft  bath   price  bhk
# 0  Super built-up  Area      2 BHK       1056   2.0   39.07    2
# 1            Plot  Area  4 Bedroom       2600   5.0  120.00    4
# 2        Built-up  Area      3 BHK       1440   2.0   62.00    3
# 3  Super built-up  Area      3 BHK       1521   3.0   95.00    3
# 4  Super built-up  Area      2 BHK       1200   2.0   51.00    2

# %%
data3 = data2.drop(['size'],axis=1)
data3
# Out:
#                   area_type total_sqft  bath   price  bhk
# 0      Super built-up  Area       1056   2.0   39.07    2
# 1                Plot  Area       2600   5.0  120.00    4
# 2            Built-up  Area       1440   2.0   62.00    3
# 3      Super built-up  Area       1521   3.0   95.00    3
# 4      Super built-up  Area       1200   2.0   51.00    2
# ...                     ...        ...   ...     ...  ...
# 13315        Built-up  Area       3453   4.0  231.00    5
# 13316  Super built-up  Area       3600   5.0  400.00    4
# 13317        Built-up  Area       1141   2.0   60.00    2
# 13318  Super built-up  Area       4689   4.0  488.00    4
# 13319  Super built-up  Area        550   1.0   17.00    1
#
# [13247 rows x 5 columns]

# %%
data3.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def sqft_to_num(x):
    y = x.split('-')
    if len(y)>1:
        avg = (float(y[0])+float(y[1]))/2
        return int(avg)
    try:
        return int(y[0])
    except:
        return None

# %%
data4 = data3.copy()
data4['sqft'] = data4['total_sqft'].apply(sqft_to_num)
data4 = data4.dropna()
data4.head()
# Out:
#               area_type total_sqft  bath   price  bhk    sqft
# 0  Super built-up  Area       1056   2.0   39.07    2  1056.0
# 1            Plot  Area       2600   5.0  120.00    4  2600.0
# 2        Built-up  Area       1440   2.0   62.00    3  1440.0
# 3  Super built-up  Area       1521   3.0   95.00    3  1521.0
# 4  Super built-up  Area       1200   2.0   51.00    2  1200.0

# %%
data4.isnull().sum()
# Out:
# area_type     0
# total_sqft    0
# bath          0
# price         0
# bhk           0
# sqft          0
# dtype: int64

# %%
data4.area_type.unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
data4.describe(include='all')
# Out:
#                    area_type total_sqft          bath         price  \
# count                  13114      13114  13114.000000  13114.000000
# unique                     4       1949           NaN           NaN
# top     Super built-up  Area       1200           NaN           NaN
# freq                    8663        843           NaN           NaN
# mean                     NaN        NaN      2.689111    112.017973
# std                      NaN        NaN      1.340165    149.142195
# min                      NaN        NaN      1.000000      8.000000
# 25%                      NaN        NaN      2.000000     50.000000
# 50%                      NaN        NaN      2.000000     71.000000
# 75%                      NaN        NaN      3.000000    120.000000
# max                      NaN        NaN     40.000000   3600.000000
#
#                  bhk          sqft
# count   13114.000000  13114.000000
# unique           NaN           NaN
# top              NaN           NaN
# ...

# %%
data4['price_per_sqft'] = data4['price']*100000/data4['sqft']

# %%
data4.isnull().sum()
# Out:
# area_type         0
# total_sqft        0
# bath              0
# price             0
# bhk               0
# sqft              0
# price_per_sqft    0
# dtype: int64

# %%
data5 = data4.drop(['total_sqft'],axis=1)

# %%
data5.describe(include='all')
# Out:
#                    area_type          bath         price           bhk  \
# count                  13114  13114.000000  13114.000000  13114.000000
# unique                     4           NaN           NaN           NaN
# top     Super built-up  Area           NaN           NaN           NaN
# freq                    8663           NaN           NaN           NaN
# mean                     NaN      2.689111    112.017973      2.800366
# std                      NaN      1.340165    149.142195      1.295428
# min                      NaN      1.000000      8.000000      1.000000
# 25%                      NaN      2.000000     50.000000      2.000000
# 50%                      NaN      2.000000     71.000000      3.000000
# 75%                      NaN      3.000000    120.000000      3.000000
# max                      NaN     40.000000   3600.000000     43.000000
#
#                 sqft  price_per_sqft
# count   13114.000000    1.311400e+04
# unique           NaN             NaN
# ...

# %%
data6 = data5[~(data5['bath']>data5['bhk'])]

# %%
data6.head()
# Out:
#               area_type  bath  price  bhk    sqft  price_per_sqft
# 0  Super built-up  Area   2.0  39.07    2  1056.0     3699.810606
# 2        Built-up  Area   2.0  62.00    3  1440.0     4305.555556
# 3  Super built-up  Area   3.0  95.00    3  1521.0     6245.890861
# 4  Super built-up  Area   2.0  51.00    2  1200.0     4250.000000
# 5  Super built-up  Area   2.0  38.00    2  1170.0     3247.863248

# %%
data6.isnull().sum()
# Out:
# area_type         0
# bath              0
# price             0
# bhk               0
# sqft              0
# price_per_sqft    0
# dtype: int64

# %%
plt.hist(data6.bath, bins=100)
plt.show()
(data6.bath>10).sum()
# Out:
# 7

# %%
data7 = data6[~(data6.bath > 10)]
(data7.bath>10).sum()
# Out:
# 0

# %%
data7.describe()
# Out:
#               bath         price           bhk          sqft  price_per_sqft
# count  12221.00000  12221.000000  12221.000000  12221.000000    1.222100e+04
# mean       2.52107    100.388950      2.728255   1476.989526    7.765247e+03
# std        1.06629    120.976567      1.163146   1178.200308    1.109058e+05
# min        1.00000      8.000000      1.000000      1.000000    2.678298e+02
# 25%        2.00000     48.510000      2.000000   1095.000000    4.201681e+03
# 50%        2.00000     68.000000      3.000000   1250.000000    5.290323e+03
# 75%        3.00000    108.000000      3.000000   1600.000000    6.994100e+03
# max       10.00000   2800.000000     12.000000  52272.000000    1.200000e+07

# %%
plt.hist(data7.price_per_sqft,bins=10,rwidth = 0.7)
plt.show()

# %%
data7['price_per_sqft'] = data7['price_per_sqft'].astype('int64')
data7['price_per_sqft']
# Out:
# <ipython-input-94-1d998f39e315>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data7['price_per_sqft'] = data7['price_per_sqft'].astype('int64')
# 0         3699
# 2         4305
# 3         6245
# 4         4250
# 5         3247
#          ...
# 13314     6530
# 13315     6689
# 13317     5258
# 13318    10407
# 13319     3090
# Name: price_per_sqft, Length: 12221, dtype: int64

# %%
plt.hist(data7.price_per_sqft,bins=100,rwidth = 0.7,range=(1,50000))
plt.show()

# %%
data8 = data7[~(data6.price_per_sqft > 17500)]
data8 = data8[~(data6.price_per_sqft < 3000)]
# Out:
# <ipython-input-96-40f2e9957c50>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data8 = data7[~(data6.price_per_sqft > 17500)]
# <ipython-input-96-40f2e9957c50>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data8 = data8[~(data6.price_per_sqft < 3000)]

# %%
plt.hist(data8.price_per_sqft,bins=100,rwidth = 0.7,range=(1,50000))
plt.show()

# %%
data8.describe()
# Out:
#                bath         price           bhk          sqft  price_per_sqft
# count  11382.000000  11382.000000  11382.000000  11382.000000    11382.000000
# mean       2.496046     93.465217      2.691970   1455.571516     6134.078106
# std        0.997551     84.033221      1.084435    820.206917     2762.824790
# min        1.000000     12.000000      1.000000    296.000000     3000.000000
# 25%        2.000000     50.000000      2.000000   1100.000000     4300.250000
# 50%        2.000000     69.000000      3.000000   1260.000000     5324.000000
# 75%        3.000000    104.000000      3.000000   1600.000000     6892.250000
# max       10.000000   2100.000000     12.000000  30400.000000    17500.000000

# %%
#Regression

# %%
dummies = pd.get_dummies(data8.area_type, drop_first=True)
data9 = pd.concat([data8,dummies],axis='columns')
data9
# Out:
#                   area_type  bath   price  bhk    sqft  price_per_sqft  \
# 0      Super built-up  Area   2.0   39.07    2  1056.0            3699
# 2            Built-up  Area   2.0   62.00    3  1440.0            4305
# 3      Super built-up  Area   3.0   95.00    3  1521.0            6245
# 4      Super built-up  Area   2.0   51.00    2  1200.0            4250
# 5      Super built-up  Area   2.0   38.00    2  1170.0            3247
# ...                     ...   ...     ...  ...     ...             ...
# 13314  Super built-up  Area   3.0  112.00    3  1715.0            6530
# 13315        Built-up  Area   4.0  231.00    5  3453.0            6689
# 13317        Built-up  Area   2.0   60.00    2  1141.0            5258
# 13318  Super built-up  Area   4.0  488.00    4  4689.0           10407
# 13319  Super built-up  Area   1.0   17.00    1   550.0            3090
#
#        Carpet  Area  Plot  Area  Super built-up  Area
# 0                 0           0                     1
# ...

# %%
data10 = data9.drop(['price_per_sqft','area_type'],axis=1)
X = data10.drop(['price'],axis=1)
y = data10.price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
data10
# Out:
#        bath   price  bhk    sqft  Carpet  Area  Plot  Area  \
# 0       2.0   39.07    2  1056.0             0           0
# 2       2.0   62.00    3  1440.0             0           0
# 3       3.0   95.00    3  1521.0             0           0
# 4       2.0   51.00    2  1200.0             0           0
# 5       2.0   38.00    2  1170.0             0           0
# ...     ...     ...  ...     ...           ...         ...
# 13314   3.0  112.00    3  1715.0             0           0
# 13315   4.0  231.00    5  3453.0             0           0
# 13317   2.0   60.00    2  1141.0             0           0
# 13318   4.0  488.00    4  4689.0             0           0
# 13319   1.0   17.00    1   550.0             0           0
#
#        Super built-up  Area
# 0                         1
# 2                         0
# 3                         1
# 4                         1
# 5                         1
# ...                     ...
# 13314                     1
# ...

# %%
data9.shape
# Out:
# (11382, 9)

# %%
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lin_reg.score(X_test,y_test)
# Out:
# 0.692415529026362

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=10)
cross_val_score(lin_reg, X, y, cv=cv)
# Out:
# array([0.70058036, 0.76292154, 0.70816129, 0.68800778, 0.70242597])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=3)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.724445
# 1              lasso    0.723140
# 2      decision_tree    0.638535
#
#                                          best_params
# 0                               {'normalize': False}
# 1                {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
def predict_price(area_type,sqft,bath,bhk):    
    loc_index = np.where(X.columns==area_type)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = bath
    x[1] = bhk
    x[2] = sqft
    if loc_index >= 0:
        x[loc_index] = 1

    return lin_reg.predict([x])[0]

# %%
lin_reg.predict([[2,2,1200,0,0,0]])
# Out:
# array([66.58867007])

# %%
X.columns
# Out:
# Index(['bath', 'bhk', 'sqft', 'Carpet  Area', 'Plot  Area',
#        'Super built-up  Area'],
#       dtype='object')

# %%
predict_price('Carpet  Area',1200,2,2)
# Out:
# 69.29580538350349

# %%
import pickle
with open ('banglore_house_price.pickle','wb') as f:
           pickle.dump(lin_reg,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
